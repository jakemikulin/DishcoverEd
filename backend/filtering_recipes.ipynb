# %%
import pickle as pkl

# %%
filename = "recipes_dict.pkl"
recipes_dict = pkl.load(open(filename, "rb"))

# %%
for recipe_id in recipes_dict:
    # if len(recipes_dict[recipe_id]["ingredients"]) == 0:
    #     print(recipe_id)
    #     print(recipes_dict[recipe_id])
    #     print()
    # if len(recipes_dict[recipe_id]["directions"]) == 0:
    #     print(recipe_id)
    #     print(recipes_dict[recipe_id])
    #     print()

    title = recipes_dict[recipe_id].get("title", "")
    if isinstance(title, str) and "holy" in title:
        print(recipes_dict[recipe_id]['title'])
# Out:
# Grilled Beef Steaks-Bulgaria(Govezhdy Purzholy Na Skara)
# Cholya Saalan
# Melancholy Bars
# Meloncholy Baby
# Meatloaf so Delicious It'll Make 'em Say, "holy @*^#... Tha
# (W)holy Grain Bread, Batman! (Abm)
# holy-moist chocolate cupcakes

# %%
recipes_dict[2072577]
# Out:
# {'title': 'Chicken fricasse',
#  'ingredients': '["1 can heavy whipping cream (crema de leche)", "1 cup requeijao (brazilian cream cheese)", "1 can corn", "1 cup pitted olives", "2 each chicken breast (shredded)", "1 cup shredded cheese", "1 cup shoestring potato (optional)", "1 cup water", "1 dash salt"]',
#  'directions': '["Blend together the heavy whipping cream, the cream cheese, the water and the corn", "Transfer the cream to a pot, add the chicken, the olives and the salt", "Cook until it thickens", "Add the cream to a baking dish.", "Spread the shredded cheese over the cream and bake it at 350F (180C) until it bubbles", "Spread the shoestring potato on top.", "Serve with rice"]',
#  'link': 'cookpad.com/us/recipes/341273-chicken-fricasse',
#  'source': 'Recipes1M',
#  'NER': "['corn', 'shredded cheese', 'water', 'heavy whipping cream', 'shoestring potato', 'olives', 'requeijao', 'chicken', 'salt']",
#  'site': 'cookpad.com',
#  'categories': "['Vegetable', 'Dairy', 'Plant', 'Meat', 'Maize', 'Additive']",
#  'cuisine': 'french'}
